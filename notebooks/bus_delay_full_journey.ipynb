# %% [markdown]
# # Bus Delay DSS Full Journey
#
# This notebook proves the same logic used by the backend and frontend. It should not contain a separate copy of the product logic.

# %%
from pathlib import Path
import sys

ROOT = Path.cwd().parents[0] if Path.cwd().name == 'notebooks' else Path.cwd()
sys.path.insert(0, str(ROOT))

from backend.pipeline import run_full_pipeline

# %% [markdown]
# ## Run The Complete Pipeline
#
# Generate data, validate it, analyze it, run scenarios, and produce a recommendation.

# %%
result = run_full_pipeline(write_outputs=True)
result['analysis']['kpis']

# %% [markdown]
# ## Inspect Quality
#
# A DSS should not recommend action if the data quality gate fails.

# %%
result['validation']

# %% [markdown]
# ## Compare Scenarios

# %%
result['scenarios'][:3]

# %% [markdown]
# ## Explain Recommendation

# %%
result['recommendation']
